# %% [markdown]
# # Day 4-01｜上傳與轉檔：準備自己的投籃影片
#
# > Python「黑客松」實戰分析籃球運動數據
# > Notebook 以初學 Python 學員為主：先觀察、再改變少量變數、最後才串接。

# %% [markdown]
# 目標：學生把手機拍的投籃影片放進 `assets/raw/`，Notebook 統一轉成 `assets/converted/*.mp4`。

# %%
from pathlib import Path
import sys

# 在 Colab 中先掛載 Drive；本機執行時會自動略過。
try:
    from google.colab import drive

    drive.mount("/content/drive")
except Exception:
    pass

COURSE_ROOT = Path("/content/drive/MyDrive/basketball_hackathon/course")
if not COURSE_ROOT.exists():
    # 本機或 zip 解壓後執行時，從目前資料夾往上找。
    here = Path.cwd().resolve()
    for candidate in [here, *here.parents]:
        if (candidate / "src").exists() and (candidate / "assets").exists():
            COURSE_ROOT = candidate
            break

if str(COURSE_ROOT) not in sys.path:
    sys.path.insert(0, str(COURSE_ROOT))

print("COURSE_ROOT =", COURSE_ROOT)
print("assets =", COURSE_ROOT / "assets")

# %% [markdown]
# ## 方式 A：直接上傳到 Google Drive
#
# 把影片放到：
#
# ```text
# basketball_hackathon/course/assets/raw/
# ```
#
# 建議檔名使用英文，例如：
#
# ```text
# shooting_01.mov
# ```
#
# ## 方式 B：Buzzheavier
#
# 手機上傳影片後，把下載連結貼到下面的 `BUZZHEAVIER_URL`。若連結不是直接下載連結，可能需要老師協助改成可下載 URL。

# %%
from pathlib import Path
from src.video_utils import download_file, convert_all_raw_videos, list_videos

RAW_DIR = COURSE_ROOT / "assets" / "raw"
CONVERTED_DIR = COURSE_ROOT / "assets" / "converted"
RAW_DIR.mkdir(parents=True, exist_ok=True)
CONVERTED_DIR.mkdir(parents=True, exist_ok=True)

BUZZHEAVIER_URL = ""  # TODO: 有連結再貼；沒有就留空。

if BUZZHEAVIER_URL.strip():
    out = RAW_DIR / "buzzheavier_upload.bin"
    download_file(BUZZHEAVIER_URL.strip(), out)
    print("downloaded:", out)
else:
    print("沒有提供 Buzzheavier URL，請確認影片是否已放到 assets/raw/")

print("raw videos:")
for p in list_videos(RAW_DIR):
    print("-", p.name)

# %%
# 需要系統有 ffmpeg。Colab 通常已經有。
outputs = convert_all_raw_videos(COURSE_ROOT, fps=30, max_side=1280)

if outputs:
    print("converted videos:")
    for p in outputs:
        print("-", p)
else:
    print("沒有找到原始影片。Day 4-02 仍可用合成資料先跑。")

# %%
print("目前 converted 影片：")
for p in list_videos(CONVERTED_DIR):
    print("-", p.name)
